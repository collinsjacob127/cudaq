# %% [markdown]
# # Factoring Integers With Shor's Algorithm
#
# This file is sourced from [NVIDIA Cuda-Q Docs](https://nvidia.github.io/cuda-quantum/latest/_sources/examples/python/tutorials/Shors.ipynb.txt)

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/collinsjacob127/cudaq/blob/main/python/Shors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# The most famous application of quantum computers is factoring integers using Shor's algorithm. This algorithm is particularly significant because an efficient factorization algorithm could potentially break modern asymmetric encryption schemes, such as RSA.
#
# For small integers, this quantum algorithm can be simulated on classical computers. The main challenge in classical implementation lies in the order-finding algorithm. We will first introduce the classical implementation of this algorithm as a preliminary step, and then proceed to explain the quantum order-finding algorithm.

# %% [markdown]
# First let's install some libraries.

# %%
# Already installed in our environment.yml
# %pip install -q contfrac
# %pip install -q cuda-quantum
# %pip install -q contfrac
# %pip install -q wget
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from math import gcd, log2, ceil
import numpy as np # C-compiled math
import random
import cudaq # Quantum!
from cudaq import * 
import fractions 
import matplotlib.pyplot as plt # Plotting
import contfrac # Floats as fractions
import time # Timer
import wget # Download 16-bit primes file
import os # File management

# %% [markdown]
# ## Helper Funcs & Debug Variable

# %%
DEBUG = True

# %%
class ProgressTimer:
    """
    A class to display a progress bar in the terminal with optional time tracking.

    This class provides an easy way to track the progress of loops or tasks and optionally display the elapsed time.
    
    Attributes:
    -----------
    total : int
        The total number of iterations for the progress bar.
    iteration : int
        The current iteration (defaults to 0).
    prefix : str
        The prefix string to display before the progress bar.
    suffix : str
        The suffix string to display after the progress bar.
    decimals : int
        The number of decimal places to display for the progress percentage.
    length : int
        The character length of the progress bar.
    fill : str
        The character to use to fill the progress bar.
    start_time : int
        The time (in nanoseconds) when the progress tracking started.

    Methods:
    --------
    _separate_ns(ns, as_list=False):
        Separates a time duration in nanoseconds into seconds, milliseconds, and nanoseconds.
    display_progress(iteration=None, prefix=None, suffix=None, decimals=None, length=None, fill=None, show_time=False):
        Updates and prints the progress bar with optional elapsed time.
    start_timer(desc=None):
        Resets the start time to the current time and optionally prints a description.
    show_time(desc=None):
        Prints the elapsed time since the last start time with an optional description.
    get_time():
        Returns the elapsed time in nanoseconds since the last start time as an integer.
    """

    def __init__(self, total, prefix='', suffix='', decimals=1, length=100, fill='█'):
        """
        Initializes the ProgressTimer with a total number of iterations and optional display settings.

        Parameters:
        -----------
        total : int
            The total number of iterations for the progress bar.
        prefix : str, optional
            The prefix string to display before the progress bar (default is an empty string).
        suffix : str, optional
            The suffix string to display after the progress bar (default is an empty string).
        decimals : int, optional
            The number of decimal places to display for the progress percentage (default is 1).
        length : int, optional
            The character length of the progress bar (default is 100).
        fill : str, optional
            The character to use to fill the progress bar (default is '█').
        """
        self.total = total
        self.iteration = 0
        self.prefix = prefix
        self.suffix = suffix
        self.decimals = decimals
        self.length = length
        self.fill = fill
        self.start_time = time.time_ns()  # Save the start time as a Python int

    def _separate_ns(self, ns, as_list=False):
        """
        Separates a given duration in nanoseconds into seconds, milliseconds, and remaining nanoseconds.

        Parameters:
        -----------
        ns : int
            The time duration in nanoseconds.
        as_list : bool, optional
            If True, returns a list [seconds, milliseconds, nanoseconds].
            Otherwise, returns a formatted string (default is False).
        
        Returns:
        --------
        str or list
            A string representation or list of the separated time components.
        """
        seconds = ns // 1_000_000_000  # Get the full seconds
        remainder_ns = ns % 1_000_000_000  # Get the remaining nanoseconds after seconds
        milliseconds = remainder_ns // 1_000_000  # Get the full milliseconds from the remainder
        nanoseconds = remainder_ns % 1_000_000  # Get the remaining nanoseconds
        if as_list:
            return [seconds, milliseconds, nanoseconds]
        return f'{seconds} s, {milliseconds} ms, {nanoseconds} ns'

    def display_progress(self, iteration=None, prefix=None, suffix=None, decimals=None, length=None, fill=None, show_time=False):
        """
        Displays and updates the progress bar in the terminal.

        Parameters:
        -----------
        iteration : int, optional
            The current iteration to display (default is None, which uses the stored value).
        prefix : str, optional
            The prefix string to display before the progress bar (default is the initialized prefix).
        suffix : str, optional
            The suffix string to display after the progress bar (default is the initialized suffix).
        decimals : int, optional
            The number of decimal places to display for the progress percentage (default is the initialized value).
        length : int, optional
            The character length of the progress bar (default is the initialized length).
        fill : str, optional
            The character to use to fill the progress bar (default is the initialized fill).
        show_time : bool, optional
            If True, displays the elapsed time since the progress bar was initialized (default is False).
        
        Notes:
        ------
        If `iteration` is equal to `total`, a new line is printed to indicate completion.
        """
        # Use provided parameters if they exist; otherwise, use instance variables
        self.iteration = iteration if iteration is not None else self.iteration
        prefix = prefix if prefix is not None else self.prefix
        suffix = suffix if suffix is not None else self.suffix
        decimals = decimals if decimals is not None else self.decimals
        length = length if length is not None else self.length
        fill = fill if fill is not None else self.fill

        percent = ("{0:." + str(decimals) + "f}").format(100 * (self.iteration / float(self.total)))
        filled_length = int(length * self.iteration // self.total)
        bar = fill * filled_length + '-' * (length - filled_length)
        
        # Show time if show_time is True
        time_display = ""
        if show_time:
            elapsed_ns = self.get_time()
            seconds, milliseconds, _ = self._separate_ns(elapsed_ns, as_list=True)
            time_display = f' {seconds}s {milliseconds}ms'

        # Print the progress bar
        print(f'\r{prefix} |{bar}| {percent}% {time_display} {suffix}', end="\r")

        # Print a new line when the process is complete
        if self.iteration == self.total:
            print()

    def start_timer(self, desc=None):
        """
        Resets the start time to the current time and optionally prints a description.

        Parameters:
        -----------
        desc : str, optional
            A description to print when resetting the timer (default is None).

        Example:
        --------
        >>> progress.start_timer("New task started")
        """
        self.start_time = time.time_ns()
        if desc:
            print(f'{desc}')

    def show_time(self, desc=None):
        """
        Displays the elapsed time since the last start time with an optional description.

        Parameters:
        -----------
        desc : str, optional
            A description to print before the elapsed time (default is None).

        Example:
        --------
        >>> progress.show_time("Time elapsed")
        """
        elapsed_ns = self.get_time()
        seconds, milliseconds, _ = self._separate_ns(elapsed_ns, as_list=True)
        
        if desc:
            print(f'{desc}: {seconds}s {milliseconds}ms')
        else:
            print(f'Elapsed time: {seconds}s {milliseconds}ms')

    def get_time(self):
        """
        Returns the elapsed time in nanoseconds since the last start time.

        Returns:
        --------
        int
            The elapsed time in nanoseconds as a Python integer.
        
        Example:
        --------
        >>> elapsed_ns = progress.get_time()
        >>> print(f"Elapsed time: {elapsed_ns} ns")
        """
        current_time = time.time_ns()
        return current_time - self.start_time

# %% [markdown]
# ## Shor's algorithm
# The factoring problem for an integer $N$ aims to find integers $a_1$, $a_2$ which are factors of $N$.  This problem is interesting when $N$ is not prime and the solutions $a_1$ and $a_2$ are non-trivial.  In other words, we will attempt to find integers $a_1$ and $a_2$ satisfying $N=a_1\cdot a_2$ with $a_1\neq 1$ and $a_2\neq 1$.
#
# The algorithm consists of two ideas:
#
# * Reduce the problem of factoring the integer $N$ to the order-finding problem.
# * Solve the order-finding problem:
# Given integers $a$ and $N$ so that $a$ and $N$ share no common factors (i.e., the greatest common divisor of $a$ and $N$ is 1), find the smallest positive integer which satisfies $a^r \equiv 1 \mod N$.  This value $r$ is refered to as the *order of* $a \mod N$.
#
# These two ideas are combined in the following steps in Shor's algorithm:
#
# 0. Rule out the easy case that $N$ is even
# 1. Select a random integer $a$ between $2$ and $N-1$
# 2. Check to see if $a$ is a factor of $N$ (if so we're done!)
# 3. Find the order of $a \mod N$, (i.e., find $r$ so that $a^r\equiv 1 \mod N$)
# 4. Check to see if $a^{\frac{r}{2}}-1$ or $a^{\frac{r}{2}}+1$ are integers and share common, non-trivial, divisors with $N$ (if so we're done!)
# 5. If no factor is found, repeat steps 1 through 4 above.
#
# The function `shors_algorithm` below outlines these steps for both the classical and the quantum implementation of Shor's algorithm. For the purposes of demonstration, we will also control the initial random integer selected in step 1 so that we can investigate cases in which the selected integer produces common divisors of $N$ in step 4 and others in which step 4 produces no common factors.
#
#
# **Note about terminology:** Some literature refers to the "period-finding problem" in Shor's algorithm.  The order-finding problem, as we have described above, can be recast as finding the period of the function $f(x) = a^x\mod N$, by noticing that the period of $f(x)$ is one more than the order of $a\mod N$. The period finding problem is more general than the order-finding problem since it aims to find the period of any periodic function, not just modular exponentiation.

# %%
def shors_algorithm(N, initial, quantum):
    """ Factor N using Shor's algorithm with initial starting value and choice of 
    using either classical or quantum approach for the period finding step
    Parameters
    ----------
    N: int 
        Integer to be factored (assumed to be non-prime and >1)
    initial: int 
        Initial choice of the random integer between 2 and N-1
    quantum: boolean
        True if we will call the quantum order-finding algorithm, and false if we call the classical one for step 3.   
        
    Returns
    -------
    a1, a2: int
        Non-trivial factors of N
    """

    # 0. Check to see if N is even.
    if N % 2 == 0:
        divisor1 = 2
        divisor2 = N // 2
        if DEBUG:
            print("Found factors:", divisor1, divisor2)
        return (divisor1, divisor2)

    attempts = [initial]
    max_iter = 10_000
    while (len(attempts) < max_iter):
        # 1. Select a random integer between 2 and N-1
        if len(attempts) == 1:
            a = initial
        else:
            a = random.choice(
                [n for n in range(N - 1) if n not in attempts and n != 1])

        # 2. See if the integer selected in step 1 happens to factor N
        if DEBUG:
            print("Trying a =", a)
        divisor1 = gcd(a, N)
        if divisor1 != 1:
            divisor2 = N // divisor1
            if DEBUG:
                print("Found factors of N={} by chance: {} and {}".format(N, divisor1, divisor2))
            return (divisor1, divisor2)

        # 3. Find the order of a mod N (i.e., r, where a^r = 1 (mod N))
        if quantum == True:
            r = find_order_quantum(a, N)
        else:
            r = find_order_classical(a, N)
        if DEBUG:
            print("The order of a = {} is {}".format(a,r))

        # 4. If the order of a is found and it is
        # * even and
        # * not a^(r/2) = -1 (mod N),
        # then test a^(r/2)-1 and a^(r/2)+1 to see if they share factors with N.
        # We also want to rule out the case of finding the trivial factors: 1 and N.
        divisor1, divisor2 = test_order(a, r, N)
        if (divisor1 != 0):  # test_order will return a 0 if no factor is found
            if DEBUG:
                print("Found factors of N = {}: {} and {}".format(N,divisor1, divisor2))
                print(f'{len(attempts)} attempts')
            return divisor1, divisor2

        # 5. Repeat
        if DEBUG:
            print("retrying...")
        attempts.append(a)

# %% [markdown]
# Let's first explore the idea of reducing the factoring problem into the order-finding problem. This gets captured in step 4 described above.  In this step, we have already established that $a$ and $N$ share no factors other than $1$ (i.e., $\gcd(a,N)=1$) and we have found $r$, the order of $a\mod N.$  With this information we know that $a^r \equiv 1 \mod N.$  Rewritten in another way:
# $$
# a^r -1 \equiv 0\mod N
# \tag{1}.
# $$
#
#  If $r$ is even, we can rewrite $a^r$ as $x^2$ where $x=a^\frac{r}{2}$. Next, we can factor equation $(1)$ using the identity $x^2-1 = (x-1)(x+1)$:
#  $$
#  (a^{\frac{r}{2}} - 1)(a^{\frac{r}{2}} + 1) \equiv 0\mod N
# \tag{2}.
# $$
#
# If, in addition, the equation
# $$
# a^{\frac{r}{2}}  \not\equiv -1\mod N
# \tag{3}
# $$
# is satisfied, then  at least one of the terms $a^{\frac{r}{2}} - 1$ or $a^{\frac{r}{2}} + 1$ must share a common factor with $N$. [Peter Shor](https://arxiv.org/abs/quant-ph/9508027) demonstrated that there is greater than a $50\%$ chance of randomly selecting a value for $a$ satisfying these properties.
#
# The code block below defines a function that tests whether $r$ is even and whether equation $(3)$ is satisfied and searches for a non-trivial factor of $N$.

# %%
def test_order(a, r, N):
    """Checks whether or not a^(r/2)+1 or a^(r/2)-1 share a non-trivial common factor with N
    Parameters
    ----------
    a: int
    r: int
    N: int
    
    Returns
    -------
    int, int factors of N, if found; 0,0 otherwise  
    """

    if r != None and (r % 2 == 0) and a**r % N == 1:
        if (a**(int(r / 2))) % N != -1:
            possible_factors = [gcd(r - 1, N), gcd(r + 1, N)]
            for test_factor in possible_factors:
                if test_factor != 1 and test_factor != N:
                    return np.uint64(test_factor), np.uint64(N // test_factor)
    # period did not produce a factor
    # There were cases where it would return none and break everything
    if DEBUG:
        print('No non-trivial factor found')
    return (0, 0)

# %% [markdown]
# ### Solving the order-finding problem classically
#
# The key component of Shor's algorithm is an efficient quantum algorithm to find the order $r$ of $a \mod N$. While a straightforward classical algorithm can solve this problem, it is notably inefficient:

# %%
def find_order_classical(a, N):
    """A naive classical method to find the order r of a (mod N).
    Parameters
    ----------
    a: int
        an integer in the interval [2,N-1]
    N: int
    
    Returns
    -------
    r: int 
        Period of a^x (mod N)
    """
    assert 1 < a and a < N
    r = 1
    y = a
    while y != 1:
        y = y * a % N
        r += 1
    return np.uint32(r)

# %% [markdown]
# Let's see how Shor's algorithm works on a few examples using the classical order-finding problem.  Notice how often our choice of value for the initial guess for $a$ produces factors of $N$.

# %%
# Path to file of 16 bit primes
fp = '16bit-primes.txt'

### Get Actual Runtime of Classical Implementation ###
def read_nbit_sp_factors(nbits, 
                     filepath, 
                     include_lower=False):
    """
    Opens a csv of prime numbers and returns a list of all primes between 
    sqrt(2^(nbits-1)) and sqrt(2^(nbits)-1). This ensures that any two randomly 
    selected bits will produce a semiprime necessitating n-bits.

    Parameters
    ----------
    nbits : int
        If nbits is 4, will produce potential factors of a semiprime 
        that needs exactly 8-bits.
    include_lower : bool
        If include_lower is True & nbits is 4, returns factors of a
        semiprime that needs at most 8-bits

    Returns
    -------
    list(int)
        A list of factors, any two of which will produce an n-bit semiprime.
    """
    f = open(filepath, mode="r")
    # Read primes from the file
    primes = np.array(f.readlines()).astype(int)
    # Filter primes to within the boundaries of our bitspace
    if not include_lower:
        # Smallest factor of n-bit 
        low_bound = np.ceil(np.sqrt(pow(2, nbits-1)))
        primes = np.extract(primes >= low_bound, primes)
    # Largest factor of n-bit semiprime
    upper_bound = np.floor(np.sqrt(pow(2, nbits)-1))
    # Extract 
    return np.extract(primes <= upper_bound, primes)

def test_classical_times(bit_list=[16], 
                         sample_size=10, 
                         include_lower=False,
                         show_progress=True,
                         primes_filepath=fp,
                         save_path_prefix='times_out/classical/',
                         save=True):
    """ 
    Tests runtimes of Shor's classical implementation.
    
    Parameters
    ----------
    bit_list : list(int) 
        A list of semiprime bit-sizes. Primes will be pulled
        to generate a semiprime of the requested size.
    sample_size : int
        For each bitsize in bit_list, a sample_size 
        number of semiprimes will be tested, and the
        mean of their times will be appended to mean_times
    show_progress : bool
        Whether or not to print the title and loading bar
    primes_filepath : string
        File where a list of primes numbers is stored.
    save : bool
        save=True will save these times and their corresponding
        bitsizes to a file in save_path_prefix
    save_path_prefix : string
        Path to the folder where these outputs are stored

    Returns
    -------
    list(int)
        The mean runtimes in nanoseconds 'A', such that A[i] is
        the mean runtime for semiprimes of bitsize bit_list[i].
    """
    sample_prog = ProgressTimer(total=sample_size, length=25)
    fulltime_start = sample_prog.get_time()
    if DEBUG or show_progress:
        pass
        # Correct usage to start a timer (call start_timer)
        sample_prog.start_timer(f'Computing Shor\'s Classical Runtimes' + \
                                f' on {bit_list}-bit semiprimes')
    indiv_prog = ProgressTimer(total=1)
    mean_times = []

    for i, n in enumerate(bit_list):
        sample_prog.start_timer() 

        # Pull two prime factors to make an n-bit semiprime
        primes = read_nbit_sp_factors(n, fp, include_lower=include_lower)
        if len(primes) < 2:
            print("Too few bits for multiple factors, try include_lower")
        
        if save:
            # Filename to identify this run
            fname_id = f'{bit_list[0]}-{bit_list[len(bit_list)-1]}' \
                if len(bit_list) > 1 else f'{bit_list[0]}'
            # Setup full filepath
            filepath = save_path_prefix + fname_id + ' classical.txt'
            # Ensure save directory exists
            os.makedirs(save_path_prefix, exist_ok=True)
        
        # Timer init for this bit size batch
        sample_times = []

        for j in range(sample_size):
            # Pull two n-bit prime numbers from the file
            two_primes = np.random.choice(primes, 2, replace=False)
            # Update progress
            prefix = f'{n}-bit {j+1}/{sample_size}: {two_primes} '
            sample_prog.display_progress(iteration=j,
                                         prefix=prefix,
                                         show_time=True)
            # Multiply to get our semiprime
            semiprime = two_primes[0] * two_primes[1] 
            # Get a decent starting value for 'a'
            # TODO: Improve starting value for faster runs?
            initial_value_to_start = int(np.sqrt(semiprime)) - 1 
            
            if DEBUG:
                title = f'{n}-bit Classical Shors, {two_primes}' 
            else:
                title = None
            
            # Start Timer for individual run
            indiv_prog.start_timer()
            # Run our algorithm
            shors_algorithm(semiprime, initial_value_to_start, False)
            # Save our output time
            sample_times.append(indiv_prog.get_time())
            sample_prog.display_progress(iteration=j+1,
                                         prefix=prefix,
                                         show_time=True)
        
        # Get mean runtime
        samp_mean = np.mean(sample_times)
        
        if save:
            mode = 'w' if i == 0 else 'a'
            with open(filepath, mode) as f:
                f.write(' '.join(map(str, [n, samp_mean])) + '\n')
        
        # Display time that this batch of semiprimes took, total.
        if show_progress and len(bit_list) > 1:
            sample_prog.start_timer()  # Restart timer for next batch

        mean_times.append(samp_mean)

    if DEBUG or show_progress:
        pass
        # elapsed_ns = sample_prog.get_time() - fulltime_start
        # print("Shor's Classical Runtimes completed" + \
        #       f' in {sample_prog._separate_ns(elapsed_ns)}')
    
    return mean_times

# %%
if not os.path.exists(fp):
    wget.download('https://raw.githubusercontent.com/collinsjacob127/cudaq/main/python/16bit-primes.txt', fp)

# Example usage for testing
bit_list = [12, 13, 14, 15, 16]
sample_size = 10
times = test_classical_times(bit_list, sample_size)
# Out:
# Computing Shor's Classical Runtimes on [12, 13, 14, 15, 16]-bit semiprimes
# Trying a = 58[59 61]  |-------------------------| 0.0%  0s 8ms
# The order of a = 58 is 10
# No non-trivial factor found
# retrying...
# Trying a = 1496
# The order of a = 1496 is 348
# No non-trivial factor found
# retrying...
# Trying a = 2358
# The order of a = 2358 is 348
# No non-trivial factor found
# retrying...
# Trying a = 3066
# The order of a = 3066 is 435
# No non-trivial factor found
# retrying...
# Trying a = 2057
# The order of a = 2057 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 19
# The order of a = 19 is 870
# No non-trivial factor found
# retrying...
# Trying a = 1191
# The order of a = 1191 is 348
# No non-trivial factor found
# retrying...
# Trying a = 537
# The order of a = 537 is 870
# No non-trivial factor found
# retrying...
# Trying a = 863
# The order of a = 863 is 290
# No non-trivial factor found
# retrying...
# Trying a = 2803
# The order of a = 2803 is 290
# No non-trivial factor found
# retrying...
# Trying a = 3306
# The order of a = 3306 is 870
# No non-trivial factor found
# retrying...
# Trying a = 2054
# The order of a = 2054 is 290
# No non-trivial factor found
# retrying...
# Trying a = 1863
# The order of a = 1863 is 580
# No non-trivial factor found
# retrying...
# Trying a = 1466
# The order of a = 1466 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 1566
# The order of a = 1566 is 290
# No non-trivial factor found
# retrying...
# Trying a = 1870
# The order of a = 1870 is 348
# No non-trivial factor found
# retrying...
# Trying a = 2023
# The order of a = 2023 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 1624
# The order of a = 1624 is 580
# No non-trivial factor found
# retrying...
# Trying a = 3348
# The order of a = 3348 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 1529
# The order of a = 1529 is 870
# No non-trivial factor found
# retrying...
# Trying a = 1921
# The order of a = 1921 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 3573
# The order of a = 3573 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 1300
# The order of a = 1300 is 870
# No non-trivial factor found
# retrying...
# Trying a = 103
# The order of a = 103 is 870
# No non-trivial factor found
# retrying...
# Trying a = 66
# The order of a = 66 is 870
# No non-trivial factor found
# retrying...
# Trying a = 3452
# The order of a = 3452 is 870
# No non-trivial factor found
# retrying...
# Trying a = 2792
# The order of a = 2792 is 87
# No non-trivial factor found
# retrying...
# Trying a = 2053
# The order of a = 2053 is 348
# No non-trivial factor found
# retrying...
# Trying a = 3495
# The order of a = 3495 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 2479
# The order of a = 2479 is 30
# No non-trivial factor found
# retrying...
# Trying a = 1356
# The order of a = 1356 is 6
# No non-trivial factor found
# retrying...
# Trying a = 1192
# The order of a = 1192 is 580
# No non-trivial factor found
# retrying...
# Trying a = 1775
# The order of a = 1775 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 1416
# Found factors of N=3599 by chance: 59 and 61
# Trying a = 52[61 47]  |██-----------------------| 10.0%  0s 44ms
# The order of a = 52 is 230
# No non-trivial factor found
# retrying...
# Trying a = 923
# The order of a = 923 is 460
# No non-trivial factor found
# retrying...
# Trying a = 826
# The order of a = 826 is 460
# No non-trivial factor found
# retrying...
# Trying a = 1353
# The order of a = 1353 is 92
# No non-trivial factor found
# retrying...
# Trying a = 1761
# The order of a = 1761 is 460
# No non-trivial factor found
# retrying...
# Trying a = 1987
# The order of a = 1987 is 1380
# No non-trivial factor found
# retrying...
# Trying a = 1829
# The order of a = 1829 is 46
# No non-trivial factor found
# retrying...
# Trying a = 2288
# The order of a = 2288 is 1380
# No non-trivial factor found
# retrying...
# Trying a = 1922
# The order of a = 1922 is 1380
# No non-trivial factor found
# retrying...
# Trying a = 1310
# The order of a = 1310 is 276
# No non-trivial factor found
# retrying...
# Trying a = 770
# The order of a = 770 is 460
# No non-trivial factor found
# retrying...
# Trying a = 1969
# The order of a = 1969 is 1380
# No non-trivial factor found
# retrying...
# Trying a = 1963
# The order of a = 1963 is 92
# No non-trivial factor found
# retrying...
# Trying a = 257
# The order of a = 257 is 138
# No non-trivial factor found
# retrying...
# Trying a = 2514
# The order of a = 2514 is 138
# No non-trivial factor found
# retrying...
# Trying a = 2327
# The order of a = 2327 is 115
# No non-trivial factor found
# retrying...
# Trying a = 369
# The order of a = 369 is 230
# No non-trivial factor found
# retrying...
# Trying a = 2154
# The order of a = 2154 is 690
# No non-trivial factor found
# retrying...
# Trying a = 1085
# The order of a = 1085 is 138
# No non-trivial factor found
# retrying...
# Trying a = 704
# The order of a = 704 is 20
# No non-trivial factor found
# retrying...
# Trying a = 1952
# Found factors of N=2867 by chance: 61 and 47
# Trying a = 58[59 61]  |█████--------------------| 20.0%  0s 57ms
# The order of a = 58 is 10
# No non-trivial factor found
# retrying...
# Trying a = 3011
# The order of a = 3011 is 870
# No non-trivial factor found
# retrying...
# Trying a = 3272
# The order of a = 3272 is 870
# No non-trivial factor found
# retrying...
# Trying a = 680
# The order of a = 680 is 290
# No non-trivial factor found
# retrying...
# Trying a = 3249
# The order of a = 3249 is 435
# No non-trivial factor found
# retrying...
# Trying a = 3227
# The order of a = 3227 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 851
# The order of a = 851 is 145
# No non-trivial factor found
# retrying...
# Trying a = 3487
# The order of a = 3487 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 957
# The order of a = 957 is 870
# No non-trivial factor found
# retrying...
# Trying a = 2029
# The order of a = 2029 is 870
# No non-trivial factor found
# retrying...
# Trying a = 3044
# The order of a = 3044 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 2761
# The order of a = 2761 is 870
# No non-trivial factor found
# retrying...
# Trying a = 3558
# The order of a = 3558 is 290
# No non-trivial factor found
# retrying...
# Trying a = 3536
# The order of a = 3536 is 1740
# No non-trivial factor found
# retrying...
# Trying a = 1658
# The order of a = 1658 is 116
# No non-trivial factor found
# retrying...
# Trying a = 2829
# The order of a = 2829 is 580
# No non-trivial factor found
# retrying...
# Trying a = 1830
# Found factors of N=3599 by chance: 61 and 59
# Trying a = 51[47 59]  |███████------------------| 30.0%  0s 69ms
# The order of a = 51 is 667
# No non-trivial factor found
# retrying...
# Trying a = 848
# The order of a = 848 is 667
# No non-trivial factor found
# retrying...
# Trying a = 2254
# The order of a = 2254 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2148
# The order of a = 2148 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2698
# The order of a = 2698 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1237
# The order of a = 1237 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 253
# The order of a = 253 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1047
# The order of a = 1047 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2608
# The order of a = 2608 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1003
# Found factors of N=2773 by chance: 59 and 47
# Trying a = 51[47 59]  |██████████---------------| 40.0%  0s 76ms
# The order of a = 51 is 667
# No non-trivial factor found
# retrying...
# Trying a = 444
# The order of a = 444 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1530
# The order of a = 1530 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1758
# The order of a = 1758 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 119
# The order of a = 119 is 23
# No non-trivial factor found
# retrying...
# Trying a = 1899
# The order of a = 1899 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2510
# The order of a = 2510 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 849
# The order of a = 849 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 468
# The order of a = 468 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 88
# The order of a = 88 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1444
# The order of a = 1444 is 667
# No non-trivial factor found
# retrying...
# Trying a = 679
# The order of a = 679 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1886
# The order of a = 1886 is 667
# No non-trivial factor found
# retrying...
# Trying a = 2047
# The order of a = 2047 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1795
# The order of a = 1795 is 667
# No non-trivial factor found
# retrying...
# Trying a = 332
# The order of a = 332 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1403
# The order of a = 1403 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2190
# The order of a = 2190 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1806
# The order of a = 1806 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1625
# The order of a = 1625 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2297
# The order of a = 2297 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 316
# The order of a = 316 is 667
# No non-trivial factor found
# retrying...
# Trying a = 832
# The order of a = 832 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 491
# The order of a = 491 is 667
# No non-trivial factor found
# retrying...
# Trying a = 2235
# The order of a = 2235 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 519
# The order of a = 519 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1062
# Found factors of N=2773 by chance: 59 and 47
# Trying a = 51[59 47]  |████████████-------------| 50.0%  0s 97ms
# The order of a = 51 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1828
# The order of a = 1828 is 46
# No non-trivial factor found
# retrying...
# Trying a = 2716
# The order of a = 2716 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 884
# The order of a = 884 is 46
# No non-trivial factor found
# retrying...
# Trying a = 1954
# The order of a = 1954 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1792
# The order of a = 1792 is 667
# No non-trivial factor found
# retrying...
# Trying a = 140
# The order of a = 140 is 58
# No non-trivial factor found
# retrying...
# Trying a = 1487
# The order of a = 1487 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1102
# The order of a = 1102 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2028
# The order of a = 2028 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1889
# The order of a = 1889 is 23
# No non-trivial factor found
# retrying...
# Trying a = 2771
# The order of a = 2771 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1853
# The order of a = 1853 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1894
# The order of a = 1894 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 877
# The order of a = 877 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 239
# The order of a = 239 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1353
# The order of a = 1353 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1985
# The order of a = 1985 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1730
# The order of a = 1730 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1230
# The order of a = 1230 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2684
# The order of a = 2684 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 465
# The order of a = 465 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 656
# The order of a = 656 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1426
# The order of a = 1426 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1709
# The order of a = 1709 is 667
# No non-trivial factor found
# retrying...
# Trying a = 928
# The order of a = 928 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1322
# The order of a = 1322 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1559
# The order of a = 1559 is 667
# No non-trivial factor found
# retrying...
# Trying a = 58
# The order of a = 58 is 46
# No non-trivial factor found
# retrying...
# Trying a = 1157
# The order of a = 1157 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1608
# The order of a = 1608 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 357
# The order of a = 357 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1325
# The order of a = 1325 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1856
# The order of a = 1856 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1442
# The order of a = 1442 is 667
# No non-trivial factor found
# retrying...
# Trying a = 2609
# The order of a = 2609 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 664
# The order of a = 664 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1042
# The order of a = 1042 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 858
# The order of a = 858 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2321
# The order of a = 2321 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1123
# The order of a = 1123 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2683
# The order of a = 2683 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1382
# The order of a = 1382 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2606
# The order of a = 2606 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1038
# The order of a = 1038 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1783
# The order of a = 1783 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 41
# The order of a = 41 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2754
# The order of a = 2754 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1074
# The order of a = 1074 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 679
# The order of a = 679 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2262
# The order of a = 2262 is 667
# No non-trivial factor found
# retrying...
# Trying a = 309
# The order of a = 309 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1192
# The order of a = 1192 is 667
# No non-trivial factor found
# retrying...
# Trying a = 143
# The order of a = 143 is 667
# No non-trivial factor found
# retrying...
# Trying a = 853
# The order of a = 853 is 667
# No non-trivial factor found
# retrying...
# Trying a = 72
# The order of a = 72 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2522
# The order of a = 2522 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1490
# The order of a = 1490 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2401
# The order of a = 2401 is 667
# No non-trivial factor found
# retrying...
# Trying a = 938
# The order of a = 938 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 402
# The order of a = 402 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 638
# The order of a = 638 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1273
# The order of a = 1273 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 453
# The order of a = 453 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1837
# The order of a = 1837 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1227
# The order of a = 1227 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2642
# The order of a = 2642 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 5
# The order of a = 5 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 112
# The order of a = 112 is 667
# No non-trivial factor found
# retrying...
# Trying a = 2554
# The order of a = 2554 is 667
# No non-trivial factor found
# retrying...
# Trying a = 381
# The order of a = 381 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1439
# The order of a = 1439 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 200
# The order of a = 200 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 441
# The order of a = 441 is 667
# No non-trivial factor found
# retrying...
# Trying a = 161
# The order of a = 161 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 883
# The order of a = 883 is 667
# No non-trivial factor found
# retrying...
# Trying a = 442
# The order of a = 442 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2234
# The order of a = 2234 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1421
# The order of a = 1421 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2230
# The order of a = 2230 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 966
# The order of a = 966 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2373
# The order of a = 2373 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2351
# The order of a = 2351 is 58
# No non-trivial factor found
# retrying...
# Trying a = 6
# The order of a = 6 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 723
# The order of a = 723 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1331
# The order of a = 1331 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 847
# The order of a = 847 is 29
# No non-trivial factor found
# retrying...
# Trying a = 628
# The order of a = 628 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 909
# The order of a = 909 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1725
# The order of a = 1725 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 838
# The order of a = 838 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1071
# The order of a = 1071 is 667
# No non-trivial factor found
# retrying...
# Trying a = 2046
# The order of a = 2046 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1248
# The order of a = 1248 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 719
# The order of a = 719 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1572
# The order of a = 1572 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 99
# The order of a = 99 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1967
# The order of a = 1967 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1293
# The order of a = 1293 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2525
# The order of a = 2525 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2129
# The order of a = 2129 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1354
# The order of a = 1354 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2275
# The order of a = 2275 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2568
# The order of a = 2568 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1866
# The order of a = 1866 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 632
# The order of a = 632 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 152
# The order of a = 152 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2191
# The order of a = 2191 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2662
# The order of a = 2662 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1037
# The order of a = 1037 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 1444
# The order of a = 1444 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1377
# The order of a = 1377 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1128
# Found factors of N=2773 by chance: 47 and 59
# Trying a = 48[53 47]  |███████████████----------| 60.0%  0s 287ms
# The order of a = 48 is 52
# No non-trivial factor found
# retrying...
# Trying a = 1428
# The order of a = 1428 is 1196
# No non-trivial factor found
# retrying...
# Trying a = 419
# The order of a = 419 is 1196
# No non-trivial factor found
# retrying...
# Trying a = 2361
# The order of a = 2361 is 598
# No non-trivial factor found
# retrying...
# Trying a = 810
# The order of a = 810 is 598
# No non-trivial factor found
# retrying...
# Trying a = 1692
# Found factors of N=2491 by chance: 47 and 53
# Trying a = 48[47 53]  |█████████████████--------| 70.0%  0s 290ms
# The order of a = 48 is 52
# No non-trivial factor found
# retrying...
# Trying a = 2080
# The order of a = 2080 is 299
# No non-trivial factor found
# retrying...
# Trying a = 2144
# The order of a = 2144 is 598
# No non-trivial factor found
# retrying...
# Trying a = 2255
# The order of a = 2255 is 26
# No non-trivial factor found
# retrying...
# Trying a = 1272
# Found factors of N=2491 by chance: 53 and 47
# Trying a = 51[59 47]  |████████████████████-----| 80.0%  0s 292ms
# The order of a = 51 is 667
# No non-trivial factor found
# retrying...
# Trying a = 1118
# The order of a = 1118 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 790
# The order of a = 790 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 2533
# The order of a = 2533 is 1334
# No non-trivial factor found
# retrying...
# Trying a = 893
# Found factors of N=2773 by chance: 47 and 59
# Trying a = 54 [53 59]  |██████████████████████---| 90.0%  0s 295ms
# The order of a = 54 is 58
# No non-trivial factor found
# retrying...
# Trying a = 1365
# The order of a = 1365 is 754
# No non-trivial factor found
# retrying...
# Trying a = 1510
# The order of a = 1510 is 1508
# No non-trivial factor found
# retrying...
# Trying a = 1430
# The order of a = 1430 is 58
# No non-trivial factor found
# retrying...
# Trying a = 2995
# The order of a = 2995 is 1508
# No non-trivial factor found
# retrying...
# Trying a = 51
# The order of a = 51 is 1508
# No non-trivial factor found
# retrying...
# Trying a = 2377
# The order of a = 2377 is 1508
# No non-trivial factor found
# retrying...
# Trying a = 137
# The order of a = 137 is 1508
# No non-trivial factor found
# retrying...
# Trying a = 1481
# The order of a = 1481 is 1508
# No non-trivial factor found
# retrying...
# Trying a = 1908
# Found factors of N=3127 by chance: 53 and 59
# 12-bit 10/10: [53 59]  |█████████████████████████| 100.0%  0s 304ms
# Trying a = 71[79 67]  |-------------------------| 0.0%  0s 4ms
# The order of a = 71 is 858
# No non-trivial factor found
# retrying...
# Trying a = 4310
# The order of a = 4310 is 429
# No non-trivial factor found
# retrying...
# Trying a = 653
# The order of a = 653 is 858
# No non-trivial factor found
# retrying...
# Trying a = 656
# The order of a = 656 is 66
# No non-trivial factor found
# retrying...
# Trying a = 3713
# Found factors of N=5293 by chance: 79 and 67
# Trying a = 78[89 71]  |██-----------------------| 10.0%  0s 9ms
# The order of a = 78 is 770
# No non-trivial factor found
# retrying...
# Trying a = 1814
# The order of a = 1814 is 28
# No non-trivial factor found
# retrying...
# Trying a = 785
# The order of a = 785 is 770
# No non-trivial factor found
# retrying...
# Trying a = 1251
# The order of a = 1251 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 3301
# The order of a = 3301 is 770
# No non-trivial factor found
# retrying...
# Trying a = 2974
# The order of a = 2974 is 280
# No non-trivial factor found
# retrying...
# Trying a = 5501
# The order of a = 5501 is 308
# No non-trivial factor found
# retrying...
# Trying a = 3386
# The order of a = 3386 is 385
# No non-trivial factor found
# retrying...
# Trying a = 1942
# The order of a = 1942 is 110
# No non-trivial factor found
# retrying...
# Trying a = 2638
# The order of a = 2638 is 770
# No non-trivial factor found
# retrying...
# Trying a = 3643
# The order of a = 3643 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 2929
# The order of a = 2929 is 770
# No non-trivial factor found
# retrying...
# Trying a = 30
# The order of a = 30 is 616
# No non-trivial factor found
# retrying...
# Trying a = 5750
# The order of a = 5750 is 88
# No non-trivial factor found
# retrying...
# Trying a = 6053
# The order of a = 6053 is 35
# No non-trivial factor found
# retrying...
# Trying a = 1910
# The order of a = 1910 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4843
# The order of a = 4843 is 280
# No non-trivial factor found
# retrying...
# Trying a = 4884
# The order of a = 4884 is 770
# No non-trivial factor found
# retrying...
# Trying a = 5908
# The order of a = 5908 is 140
# No non-trivial factor found
# retrying...
# Trying a = 4832
# The order of a = 4832 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 617
# The order of a = 617 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3094
# The order of a = 3094 is 308
# No non-trivial factor found
# retrying...
# Trying a = 1706
# The order of a = 1706 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3427
# The order of a = 3427 is 385
# No non-trivial factor found
# retrying...
# Trying a = 3271
# The order of a = 3271 is 55
# No non-trivial factor found
# retrying...
# Trying a = 5469
# The order of a = 5469 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 85
# The order of a = 85 is 110
# No non-trivial factor found
# retrying...
# Trying a = 5076
# The order of a = 5076 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5531
# The order of a = 5531 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 859
# The order of a = 859 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4212
# The order of a = 4212 is 616
# No non-trivial factor found
# retrying...
# Trying a = 5212
# The order of a = 5212 is 770
# No non-trivial factor found
# retrying...
# Trying a = 5725
# The order of a = 5725 is 616
# No non-trivial factor found
# retrying...
# Trying a = 1843
# The order of a = 1843 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 2021
# The order of a = 2021 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 1587
# The order of a = 1587 is 440
# No non-trivial factor found
# retrying...
# Trying a = 5405
# The order of a = 5405 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3090
# The order of a = 3090 is 77
# No non-trivial factor found
# retrying...
# Trying a = 559
# The order of a = 559 is 770
# No non-trivial factor found
# retrying...
# Trying a = 5829
# The order of a = 5829 is 770
# No non-trivial factor found
# retrying...
# Trying a = 2440
# The order of a = 2440 is 56
# No non-trivial factor found
# retrying...
# Trying a = 1586
# The order of a = 1586 is 770
# No non-trivial factor found
# retrying...
# Trying a = 3056
# The order of a = 3056 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 1694
# The order of a = 1694 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5191
# The order of a = 5191 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3397
# The order of a = 3397 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 1536
# The order of a = 1536 is 616
# No non-trivial factor found
# retrying...
# Trying a = 4334
# The order of a = 4334 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3412
# The order of a = 3412 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4707
# The order of a = 4707 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 3683
# The order of a = 3683 is 140
# No non-trivial factor found
# retrying...
# Trying a = 4066
# The order of a = 4066 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3462
# The order of a = 3462 is 220
# No non-trivial factor found
# retrying...
# Trying a = 5290
# The order of a = 5290 is 385
# No non-trivial factor found
# retrying...
# Trying a = 4093
# The order of a = 4093 is 10
# No non-trivial factor found
# retrying...
# Trying a = 3109
# The order of a = 3109 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4827
# The order of a = 4827 is 44
# No non-trivial factor found
# retrying...
# Trying a = 3884
# The order of a = 3884 is 770
# No non-trivial factor found
# retrying...
# Trying a = 3607
# The order of a = 3607 is 220
# No non-trivial factor found
# retrying...
# Trying a = 1198
# The order of a = 1198 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5403
# The order of a = 5403 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5055
# The order of a = 5055 is 220
# No non-trivial factor found
# retrying...
# Trying a = 6302
# The order of a = 6302 is 220
# No non-trivial factor found
# retrying...
# Trying a = 549
# The order of a = 549 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5196
# The order of a = 5196 is 140
# No non-trivial factor found
# retrying...
# Trying a = 2370
# The order of a = 2370 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 2194
# The order of a = 2194 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 2833
# The order of a = 2833 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4499
# The order of a = 4499 is 308
# No non-trivial factor found
# retrying...
# Trying a = 1977
# The order of a = 1977 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5839
# The order of a = 5839 is 440
# No non-trivial factor found
# retrying...
# Trying a = 2362
# The order of a = 2362 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 2497
# The order of a = 2497 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 5206
# The order of a = 5206 is 154
# No non-trivial factor found
# retrying...
# Trying a = 881
# The order of a = 881 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 783
# The order of a = 783 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 1399
# The order of a = 1399 is 385
# No non-trivial factor found
# retrying...
# Trying a = 668
# The order of a = 668 is 385
# No non-trivial factor found
# retrying...
# Trying a = 4576
# The order of a = 4576 is 56
# No non-trivial factor found
# retrying...
# Trying a = 3292
# The order of a = 3292 is 14
# No non-trivial factor found
# retrying...
# Trying a = 5623
# The order of a = 5623 is 110
# No non-trivial factor found
# retrying...
# Trying a = 1050
# The order of a = 1050 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 4227
# The order of a = 4227 is 770
# No non-trivial factor found
# retrying...
# Trying a = 2373
# The order of a = 2373 is 616
# No non-trivial factor found
# retrying...
# Trying a = 4312
# The order of a = 4312 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 1752
# The order of a = 1752 is 616
# No non-trivial factor found
# retrying...
# Trying a = 5353
# The order of a = 5353 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4384
# The order of a = 4384 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4035
# The order of a = 4035 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 1176
# The order of a = 1176 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4956
# The order of a = 4956 is 440
# No non-trivial factor found
# retrying...
# Trying a = 3984
# The order of a = 3984 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 2910
# The order of a = 2910 is 88
# No non-trivial factor found
# retrying...
# Trying a = 2412
# The order of a = 2412 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 3199
# The order of a = 3199 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 1449
# The order of a = 1449 is 770
# No non-trivial factor found
# retrying...
# Trying a = 3370
# The order of a = 3370 is 280
# No non-trivial factor found
# retrying...
# Trying a = 4145
# The order of a = 4145 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3917
# The order of a = 3917 is 35
# No non-trivial factor found
# retrying...
# Trying a = 3512
# The order of a = 3512 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 2862
# The order of a = 2862 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 4458
# The order of a = 4458 is 770
# No non-trivial factor found
# retrying...
# Trying a = 4737
# The order of a = 4737 is 308
# No non-trivial factor found
# retrying...
# Trying a = 4609
# The order of a = 4609 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 3121
# The order of a = 3121 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 1265
# The order of a = 1265 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 1859
# The order of a = 1859 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 4667
# The order of a = 4667 is 770
# No non-trivial factor found
# retrying...
# Trying a = 2610
# The order of a = 2610 is 440
# No non-trivial factor found
# retrying...
# Trying a = 3686
# The order of a = 3686 is 280
# No non-trivial factor found
# retrying...
# Trying a = 4521
# The order of a = 4521 is 308
# No non-trivial factor found
# retrying...
# Trying a = 4612
# The order of a = 4612 is 770
# No non-trivial factor found
# retrying...
# Trying a = 665
# The order of a = 665 is 308
# No non-trivial factor found
# retrying...
# Trying a = 1576
# The order of a = 1576 is 440
# No non-trivial factor found
# retrying...
# Trying a = 4871
# The order of a = 4871 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 137
# The order of a = 137 is 440
# No non-trivial factor found
# retrying...
# Trying a = 3570
# The order of a = 3570 is 308
# No non-trivial factor found
# retrying...
# Trying a = 1933
# The order of a = 1933 is 385
# No non-trivial factor found
# retrying...
# Trying a = 1810
# The order of a = 1810 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 6153
# The order of a = 6153 is 280
# No non-trivial factor found
# retrying...
# Trying a = 3921
# The order of a = 3921 is 1540
# No non-trivial factor found
# retrying...
# Trying a = 4682
# The order of a = 4682 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5964
# Found factors of N=6319 by chance: 71 and 89
# Trying a = 79[79 83]  |█████--------------------| 20.0%  0s 466ms
# Found factors of N=6557 by chance: 79 and 83
# Trying a = 79[89 73]  |███████------------------| 30.0%  0s 466ms
# The order of a = 79 is 396
# No non-trivial factor found
# retrying...
# Trying a = 6241
# The order of a = 6241 is 198
# No non-trivial factor found
# retrying...
# Trying a = 1739
# The order of a = 1739 is 792
# No non-trivial factor found
# retrying...
# Trying a = 4504
# The order of a = 4504 is 88
# No non-trivial factor found
# retrying...
# Trying a = 3569
# The order of a = 3569 is 132
# No non-trivial factor found
# retrying...
# Trying a = 6101
# The order of a = 6101 is 792
# No non-trivial factor found
# retrying...
# Trying a = 5155
# The order of a = 5155 is 792
# No non-trivial factor found
# retrying...
# Trying a = 2493
# The order of a = 2493 is 72
# No non-trivial factor found
# retrying...
# Trying a = 3535
# The order of a = 3535 is 792
# No non-trivial factor found
# retrying...
# Trying a = 5967
# The order of a = 5967 is 396
# No non-trivial factor found
# retrying...
# Trying a = 118
# The order of a = 118 is 792
# No non-trivial factor found
# retrying...
# Trying a = 2666
# The order of a = 2666 is 396
# No non-trivial factor found
# retrying...
# Trying a = 1383
# The order of a = 1383 is 792
# No non-trivial factor found
# retrying...
# Trying a = 4005
# Found factors of N=6497 by chance: 89 and 73
# Trying a = 73[67 83]  |██████████---------------| 40.0%  0s 484ms
# The order of a = 73 is 2706
# No non-trivial factor found
# retrying...
# Trying a = 965
# The order of a = 965 is 902
# No non-trivial factor found
# retrying...
# Trying a = 4411
# The order of a = 4411 is 1353
# No non-trivial factor found
# retrying...
# Trying a = 4157
# The order of a = 4157 is 902
# No non-trivial factor found
# retrying...
# Trying a = 498
# Found factors of N=5561 by chance: 83 and 67
# Trying a = 78[89 71]  |████████████-------------| 50.0%  0s 489ms
# The order of a = 78 is 770
# No non-trivial factor found
# retrying...
# Trying a = 3956
# The order of a = 3956 is 308
# No non-trivial factor found
# retrying...
# Trying a = 1683
# The order of a = 1683 is 770
# No non-trivial factor found
# retrying...
# Trying a = 5245
# The order of a = 5245 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 835
# The order of a = 835 is 20
# No non-trivial factor found
# retrying...
# Trying a = 447
# The order of a = 447 is 770
# No non-trivial factor found
# retrying...
# Trying a = 4219
# The order of a = 4219 is 308
# No non-trivial factor found
# retrying...
# Trying a = 1134
# The order of a = 1134 is 3080
# No non-trivial factor found
# retrying...
# Trying a = 5328
# The order of a = 5328 is 280
# No non-trivial factor found
# retrying...
# Trying a = 4718
# The order of a = 4718 is 7
# No non-trivial factor found
# retrying...
# Trying a = 1207
# Found factors of N=6319 by chance: 71 and 89
# Trying a = 82[89 79]  |███████████████----------| 60.0%  0s 501ms
# The order of a = 82 is 3432
# No non-trivial factor found
# retrying...
# Trying a = 1404
# The order of a = 1404 is 572
# No non-trivial factor found
# retrying...
# Trying a = 5940
# The order of a = 5940 is 1144
# No non-trivial factor found
# retrying...
# Trying a = 3489
# The order of a = 3489 is 1716
# No non-trivial factor found
# retrying...
# Trying a = 5464
# The order of a = 5464 is 3432
# No non-trivial factor found
# retrying...
# Trying a = 4907
# The order of a = 4907 is 312
# No non-trivial factor found
# retrying...
# Trying a = 3776
# The order of a = 3776 is 3432
# No non-trivial factor found
# retrying...
# Trying a = 3687
# The order of a = 3687 is 3432
# No non-trivial factor found
# retrying...
# Trying a = 5854
# The order of a = 5854 is 572
# No non-trivial factor found
# retrying...
# Trying a = 4502
# The order of a = 4502 is 8
# No non-trivial factor found
# retrying...
# Trying a = 1803
# The order of a = 1803 is 1144
# No non-trivial factor found
# retrying...
# Trying a = 5767
# Found factors of N=7031 by chance: 79 and 89
# Trying a = 75[71 83]  |█████████████████--------| 70.0%  0s 518ms
# The order of a = 75 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 2815
# The order of a = 2815 is 410
# No non-trivial factor found
# retrying...
# Trying a = 5426
# The order of a = 5426 is 287
# No non-trivial factor found
# retrying...
# Trying a = 3228
# The order of a = 3228 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 1326
# The order of a = 1326 is 287
# No non-trivial factor found
# retrying...
# Trying a = 4704
# The order of a = 4704 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 111
# The order of a = 111 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 1712
# The order of a = 1712 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2305
# The order of a = 2305 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 3742
# The order of a = 3742 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 5378
# The order of a = 5378 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4494
# The order of a = 4494 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5843
# The order of a = 5843 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4566
# The order of a = 4566 is 70
# No non-trivial factor found
# retrying...
# Trying a = 4457
# The order of a = 4457 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2204
# The order of a = 2204 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4486
# The order of a = 4486 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5758
# The order of a = 5758 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5182
# The order of a = 5182 is 82
# No non-trivial factor found
# retrying...
# Trying a = 4916
# The order of a = 4916 is 410
# No non-trivial factor found
# retrying...
# Trying a = 261
# The order of a = 261 is 287
# No non-trivial factor found
# retrying...
# Trying a = 5075
# The order of a = 5075 is 574
# No non-trivial factor found
# retrying...
# Trying a = 3997
# The order of a = 3997 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2362
# The order of a = 2362 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 2646
# The order of a = 2646 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2800
# The order of a = 2800 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4394
# The order of a = 4394 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 3948
# The order of a = 3948 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2604
# The order of a = 2604 is 287
# No non-trivial factor found
# retrying...
# Trying a = 1843
# The order of a = 1843 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5602
# The order of a = 5602 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 4057
# The order of a = 4057 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2361
# The order of a = 2361 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 615
# The order of a = 615 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 282
# The order of a = 282 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4200
# The order of a = 4200 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4953
# The order of a = 4953 is 410
# No non-trivial factor found
# retrying...
# Trying a = 4827
# The order of a = 4827 is 82
# No non-trivial factor found
# retrying...
# Trying a = 4896
# The order of a = 4896 is 70
# No non-trivial factor found
# retrying...
# Trying a = 3338
# The order of a = 3338 is 82
# No non-trivial factor found
# retrying...
# Trying a = 1935
# The order of a = 1935 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 1783
# The order of a = 1783 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 1146
# The order of a = 1146 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 516
# The order of a = 516 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5598
# The order of a = 5598 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 4113
# The order of a = 4113 is 410
# No non-trivial factor found
# retrying...
# Trying a = 3960
# The order of a = 3960 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4425
# The order of a = 4425 is 574
# No non-trivial factor found
# retrying...
# Trying a = 4534
# The order of a = 4534 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 3565
# The order of a = 3565 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5214
# The order of a = 5214 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2708
# The order of a = 2708 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4344
# The order of a = 4344 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 1858
# The order of a = 1858 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4325
# The order of a = 4325 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2789
# The order of a = 2789 is 574
# No non-trivial factor found
# retrying...
# Trying a = 1154
# The order of a = 1154 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 4701
# The order of a = 4701 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 1031
# The order of a = 1031 is 574
# No non-trivial factor found
# retrying...
# Trying a = 5334
# The order of a = 5334 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 139
# The order of a = 139 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2033
# The order of a = 2033 is 287
# No non-trivial factor found
# retrying...
# Trying a = 396
# The order of a = 396 is 574
# No non-trivial factor found
# retrying...
# Trying a = 311
# The order of a = 311 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 86
# The order of a = 86 is 1435
# No non-trivial factor found
# retrying...
# Trying a = 4389
# The order of a = 4389 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5606
# The order of a = 5606 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 3794
# The order of a = 3794 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5138
# The order of a = 5138 is 574
# No non-trivial factor found
# retrying...
# Trying a = 4054
# The order of a = 4054 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4244
# The order of a = 4244 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2198
# The order of a = 2198 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2631
# The order of a = 2631 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2181
# The order of a = 2181 is 574
# No non-trivial factor found
# retrying...
# Trying a = 1466
# The order of a = 1466 is 410
# No non-trivial factor found
# retrying...
# Trying a = 56
# The order of a = 56 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 1486
# The order of a = 1486 is 410
# No non-trivial factor found
# retrying...
# Trying a = 1901
# The order of a = 1901 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5742
# The order of a = 5742 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 1716
# The order of a = 1716 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2233
# The order of a = 2233 is 287
# No non-trivial factor found
# retrying...
# Trying a = 5213
# The order of a = 5213 is 574
# No non-trivial factor found
# retrying...
# Trying a = 3631
# The order of a = 3631 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4205
# The order of a = 4205 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2226
# The order of a = 2226 is 205
# No non-trivial factor found
# retrying...
# Trying a = 931
# The order of a = 931 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 1457
# The order of a = 1457 is 574
# No non-trivial factor found
# retrying...
# Trying a = 4133
# The order of a = 4133 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 3440
# The order of a = 3440 is 287
# No non-trivial factor found
# retrying...
# Trying a = 5369
# The order of a = 5369 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 969
# The order of a = 969 is 410
# No non-trivial factor found
# retrying...
# Trying a = 1101
# The order of a = 1101 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 4966
# The order of a = 4966 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2593
# The order of a = 2593 is 574
# No non-trivial factor found
# retrying...
# Trying a = 2332
# The order of a = 2332 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2574
# The order of a = 2574 is 35
# No non-trivial factor found
# retrying...
# Trying a = 13
# The order of a = 13 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 5782
# The order of a = 5782 is 2870
# No non-trivial factor found
# retrying...
# Trying a = 2490
# Found factors of N=5893 by chance: 83 and 71
# Trying a = 84[83 89]  |████████████████████-----| 80.0%  0s 831ms
# The order of a = 84 is 44
# No non-trivial factor found
# retrying...
# Trying a = 426
# The order of a = 426 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 272
# The order of a = 272 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 5473
# The order of a = 5473 is 902
# No non-trivial factor found
# retrying...
# Trying a = 6582
# The order of a = 6582 is 902
# No non-trivial factor found
# retrying...
# Trying a = 294
# The order of a = 294 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 5897
# The order of a = 5897 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 4706
# The order of a = 4706 is 902
# No non-trivial factor found
# retrying...
# Trying a = 3687
# The order of a = 3687 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 2664
# The order of a = 2664 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 6355
# The order of a = 6355 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 7083
# The order of a = 7083 is 328
# No non-trivial factor found
# retrying...
# Trying a = 7338
# The order of a = 7338 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 6498
# The order of a = 6498 is 82
# No non-trivial factor found
# retrying...
# Trying a = 3772
# The order of a = 3772 is 164
# No non-trivial factor found
# retrying...
# Trying a = 4146
# The order of a = 4146 is 328
# No non-trivial factor found
# retrying...
# Trying a = 7293
# The order of a = 7293 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 7222
# The order of a = 7222 is 88
# No non-trivial factor found
# retrying...
# Trying a = 2396
# The order of a = 2396 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 2559
# The order of a = 2559 is 451
# No non-trivial factor found
# retrying...
# Trying a = 203
# The order of a = 203 is 902
# No non-trivial factor found
# retrying...
# Trying a = 1542
# The order of a = 1542 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 2880
# The order of a = 2880 is 902
# No non-trivial factor found
# retrying...
# Trying a = 189
# The order of a = 189 is 902
# No non-trivial factor found
# retrying...
# Trying a = 6045
# The order of a = 6045 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 1366
# The order of a = 1366 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 5246
# The order of a = 5246 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 7330
# The order of a = 7330 is 451
# No non-trivial factor found
# retrying...
# Trying a = 4072
# The order of a = 4072 is 902
# No non-trivial factor found
# retrying...
# Trying a = 2948
# The order of a = 2948 is 902
# No non-trivial factor found
# retrying...
# Trying a = 7273
# The order of a = 7273 is 902
# No non-trivial factor found
# retrying...
# Trying a = 3888
# The order of a = 3888 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 3721
# The order of a = 3721 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 2057
# The order of a = 2057 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 2294
# The order of a = 2294 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 1035
# The order of a = 1035 is 3608
# No non-trivial factor found
# retrying...
# Trying a = 1681
# The order of a = 1681 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 2393
# The order of a = 2393 is 1804
# No non-trivial factor found
# retrying...
# Trying a = 762
# The order of a = 762 is 902
# No non-trivial factor found
# retrying...
# Trying a = 592
# The order of a = 592 is 3608
# ...
# The order of a = 24297 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 8890
# The order of a = 8890 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 21199
# The order of a = 21199 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 33595
# The order of a = 33595 is 210
# No non-trivial factor found
# retrying...
# Trying a = 14300
# The order of a = 14300 is 210
# No non-trivial factor found
# retrying...
# Trying a = 11194
# The order of a = 11194 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 19706
# The order of a = 19706 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 2175
# The order of a = 2175 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 23287
# The order of a = 23287 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 5619
# The order of a = 5619 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 3402
# The order of a = 3402 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 42002
# The order of a = 42002 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 42073
# The order of a = 42073 is 11865
# No non-trivial factor found
# retrying...
# Trying a = 26949
# The order of a = 26949 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 18437
# The order of a = 18437 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 22259
# The order of a = 22259 is 1130
# No non-trivial factor found
# retrying...
# Trying a = 7614
# The order of a = 7614 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 19054
# The order of a = 19054 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 31993
# The order of a = 31993 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 39155
# The order of a = 39155 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 38563
# The order of a = 38563 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 7606
# The order of a = 7606 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 46622
# The order of a = 46622 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 45114
# The order of a = 45114 is 1582
# No non-trivial factor found
# retrying...
# Trying a = 46477
# The order of a = 46477 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 30005
# The order of a = 30005 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 13271
# The order of a = 13271 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 29461
# The order of a = 29461 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 36156
# The order of a = 36156 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 39880
# The order of a = 39880 is 113
# No non-trivial factor found
# retrying...
# Trying a = 37610
# The order of a = 37610 is 11865
# No non-trivial factor found
# retrying...
# Trying a = 28405
# The order of a = 28405 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 26883
# The order of a = 26883 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 2243
# The order of a = 2243 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 21033
# The order of a = 21033 is 1582
# No non-trivial factor found
# retrying...
# Trying a = 44121
# The order of a = 44121 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 19053
# The order of a = 19053 is 1582
# No non-trivial factor found
# retrying...
# Trying a = 45488
# The order of a = 45488 is 1582
# No non-trivial factor found
# retrying...
# Trying a = 47220
# The order of a = 47220 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 16820
# The order of a = 16820 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 33604
# The order of a = 33604 is 1130
# No non-trivial factor found
# retrying...
# Trying a = 23810
# The order of a = 23810 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 43640
# The order of a = 43640 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 41294
# The order of a = 41294 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 39568
# The order of a = 39568 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 6443
# The order of a = 6443 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 8271
# The order of a = 8271 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 29340
# The order of a = 29340 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 8220
# The order of a = 8220 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 35200
# The order of a = 35200 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 8400
# The order of a = 8400 is 7
# No non-trivial factor found
# retrying...
# Trying a = 47892
# The order of a = 47892 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 15445
# The order of a = 15445 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 18601
# The order of a = 18601 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 17492
# The order of a = 17492 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 40430
# The order of a = 40430 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 15515
# The order of a = 15515 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 23431
# The order of a = 23431 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 47657
# The order of a = 47657 is 11865
# No non-trivial factor found
# retrying...
# Trying a = 17141
# The order of a = 17141 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 35701
# The order of a = 35701 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 7617
# The order of a = 7617 is 3390
# No non-trivial factor found
# retrying...
# Trying a = 28198
# The order of a = 28198 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 62
# The order of a = 62 is 11865
# No non-trivial factor found
# retrying...
# Trying a = 10156
# The order of a = 10156 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 18072
# The order of a = 18072 is 1695
# No non-trivial factor found
# retrying...
# Trying a = 40483
# The order of a = 40483 is 11865
# No non-trivial factor found
# retrying...
# Trying a = 31710
# The order of a = 31710 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 27754
# The order of a = 27754 is 7910
# No non-trivial factor found
# retrying...
# Trying a = 19062
# The order of a = 19062 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 5454
# The order of a = 5454 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 15112
# The order of a = 15112 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 33007
# The order of a = 33007 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 19744
# The order of a = 19744 is 3955
# No non-trivial factor found
# retrying...
# Trying a = 4983
# The order of a = 4983 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 5859
# The order of a = 5859 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 1270
# The order of a = 1270 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 28368
# The order of a = 28368 is 4746
# No non-trivial factor found
# retrying...
# Trying a = 27226
# The order of a = 27226 is 23730
# No non-trivial factor found
# retrying...
# Trying a = 24743
# Found factors of N=47897 by chance: 227 and 211
# Trying a = 209[223 199]  |██████████████████████---| 90.0%  37s 762ms
# The order of a = 209 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 14948
# The order of a = 14948 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 40166
# The order of a = 40166 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 34895
# The order of a = 34895 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 8536
# The order of a = 8536 is 333
# No non-trivial factor found
# retrying...
# Trying a = 42635
# The order of a = 42635 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 41870
# The order of a = 41870 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 3897
# The order of a = 3897 is 1221
# No non-trivial factor found
# retrying...
# Trying a = 13567
# The order of a = 13567 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 11301
# The order of a = 11301 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 14575
# The order of a = 14575 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 27609
# The order of a = 27609 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 19556
# The order of a = 19556 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 34074
# The order of a = 34074 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 1981
# The order of a = 1981 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 8793
# The order of a = 8793 is 666
# No non-trivial factor found
# retrying...
# Trying a = 26695
# The order of a = 26695 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 43240
# The order of a = 43240 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 30489
# The order of a = 30489 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 5693
# The order of a = 5693 is 814
# No non-trivial factor found
# retrying...
# Trying a = 34051
# The order of a = 34051 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 8243
# The order of a = 8243 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 3296
# The order of a = 3296 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 17172
# The order of a = 17172 is 9
# No non-trivial factor found
# retrying...
# Trying a = 35230
# The order of a = 35230 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 41581
# The order of a = 41581 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 36529
# The order of a = 36529 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 7869
# The order of a = 7869 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 11026
# The order of a = 11026 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 5374
# The order of a = 5374 is 222
# No non-trivial factor found
# retrying...
# Trying a = 4515
# The order of a = 4515 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 10762
# The order of a = 10762 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 20859
# The order of a = 20859 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 29236
# The order of a = 29236 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 18865
# The order of a = 18865 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 21439
# The order of a = 21439 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 15603
# The order of a = 15603 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 17392
# The order of a = 17392 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 28449
# The order of a = 28449 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 30019
# The order of a = 30019 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 10247
# The order of a = 10247 is 1221
# No non-trivial factor found
# retrying...
# Trying a = 26193
# The order of a = 26193 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 32529
# The order of a = 32529 is 222
# No non-trivial factor found
# retrying...
# Trying a = 22232
# The order of a = 22232 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 25824
# The order of a = 25824 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 828
# The order of a = 828 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 13854
# The order of a = 13854 is 1221
# No non-trivial factor found
# retrying...
# Trying a = 35787
# The order of a = 35787 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 21853
# The order of a = 21853 is 18
# No non-trivial factor found
# retrying...
# Trying a = 18998
# The order of a = 18998 is 222
# No non-trivial factor found
# retrying...
# Trying a = 37083
# The order of a = 37083 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 26809
# The order of a = 26809 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 19406
# The order of a = 19406 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 25938
# The order of a = 25938 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 9071
# The order of a = 9071 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 1745
# The order of a = 1745 is 198
# No non-trivial factor found
# retrying...
# Trying a = 42908
# The order of a = 42908 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 43436
# The order of a = 43436 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 7128
# The order of a = 7128 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 10995
# The order of a = 10995 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 11573
# The order of a = 11573 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 3717
# The order of a = 3717 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 28221
# The order of a = 28221 is 666
# No non-trivial factor found
# retrying...
# Trying a = 21645
# The order of a = 21645 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 37153
# The order of a = 37153 is 1221
# No non-trivial factor found
# retrying...
# Trying a = 18370
# The order of a = 18370 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 27559
# The order of a = 27559 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 22798
# The order of a = 22798 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 18392
# The order of a = 18392 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 16859
# The order of a = 16859 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 20980
# The order of a = 20980 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 30382
# The order of a = 30382 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 30446
# The order of a = 30446 is 74
# No non-trivial factor found
# retrying...
# Trying a = 23366
# The order of a = 23366 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 34266
# The order of a = 34266 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 19069
# The order of a = 19069 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 30983
# The order of a = 30983 is 814
# No non-trivial factor found
# retrying...
# Trying a = 5229
# The order of a = 5229 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 4866
# The order of a = 4866 is 33
# No non-trivial factor found
# retrying...
# Trying a = 21939
# The order of a = 21939 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 16935
# The order of a = 16935 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 30847
# The order of a = 30847 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 5718
# The order of a = 5718 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 41470
# The order of a = 41470 is 814
# No non-trivial factor found
# retrying...
# Trying a = 3789
# The order of a = 3789 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 24552
# The order of a = 24552 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 41616
# The order of a = 41616 is 1221
# No non-trivial factor found
# retrying...
# Trying a = 15481
# The order of a = 15481 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 15137
# The order of a = 15137 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 36164
# The order of a = 36164 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 10026
# The order of a = 10026 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 41934
# The order of a = 41934 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 11720
# The order of a = 11720 is 333
# No non-trivial factor found
# retrying...
# Trying a = 20839
# The order of a = 20839 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 28782
# The order of a = 28782 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 9723
# The order of a = 9723 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 24595
# The order of a = 24595 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 18895
# The order of a = 18895 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 14063
# The order of a = 14063 is 7326
# No non-trivial factor found
# retrying...
# Trying a = 3249
# The order of a = 3249 is 3663
# No non-trivial factor found
# retrying...
# Trying a = 42650
# The order of a = 42650 is 2442
# No non-trivial factor found
# retrying...
# Trying a = 14495
# Found factors of N=44377 by chance: 223 and 199
# 16-bit 10/10: [223 199]  |█████████████████████████| 100.0%  39s 723ms

# %%
my_integer = 123  #edit this value to try out a few examples
# Edit the value in the line below to try out different initial guesses for a.
# What happens when you choose a = 42 for the integer 123?
# What happens when you choose a = 100 for the integer 123?
initial_value_to_start = 42  # edit this value; it should be less than my_integer

# title = "Shor's Classical"
# start_time = start_timer(title)
# shors_algorithm(my_integer, initial_value_to_start, False)
# end_timer(start_time, title)

# %% [markdown]
# ### Solving the order-finding problem with a quantum algorithm
#
#
# The Fourier transform is a classical computation that provides a more efficient algorithm than the one encoded in `find_order_classical` for identifying the period of $f(x) = a^x\mod N$. The quantum version of the Fourier transform is the central idea of Shor's Algorithm. This efficient quantum solution derives the period from a measurement of $n = \lceil log2(N) \rceil$ qubits.
#
# The image below outlines the quantum kernel used to find the order of $a$. Notice the last step involves applying the Inverse Quantum Fourier Transform.

# %% [markdown]
# ![](images/shor_circuit.png)
#
# Figure. Circuit diagram for finding the phase of the modular multiplication gate $U|x\rangle = |a^x\mod N\rangle $, which will be used to compute the order of $a$ modulo $N$.  The number of qubits in the control register determines the accuracy of estimating the phase of $U$. The size of the work register depends on $N$. The goal of this section is to code the  diagram as a kernel named `phase_kernel`.

# %% [markdown]
# We will need to create a quantum kernel for the Inverse Quantum Fourier Transform.  Additionally we'll need to create a kernel for modular multiplication: $g(y) = ay \mod N$, which can be repeatedly applied $x$-times to $y=1$ to carry our modular exponentation $f(x)=a^x\mod N$.

# %% [markdown]
# #### Inverse quantum Fourier transform
# In the code block below we define a kernel for the quantum Fourier transform and then use `cudaq.adjoint` to create a kernel for the inverse quantum Fourier transform used in the quantum order-finding algorithm.

# %%
# Define kernels for the quantum Fourier transform and the inverse quantum Fourier transform
@cudaq.kernel
def quantum_fourier_transform(qubits: cudaq.qview):
    qubit_count = len(qubits)
    # Apply Hadamard gates and controlled rotation gates.
    for i in range(qubit_count):
        h(qubits[i])
        for j in range(i + 1, qubit_count):
            angle = (2 * np.pi) / (2**(j - i + 1))
            cr1(angle, [qubits[j]], qubits[i])


@cudaq.kernel
def inverse_qft(qubits: cudaq.qview):
    cudaq.adjoint(quantum_fourier_transform, qubits)

# %% [markdown]
# #### Quantum kernels for modular exponentiation

# %% [markdown]
# While Shor's algorithm provably can factor numbers faster than known classical techniques, the resources required for implementing Shor's algorithm are hefty. A full-scale implementation to factor an $L$-bit number could require a quantum kernel with $5L+1$ qubits to achieve accuracy for the continued fractions part of the algoirthm and as many as $72L^3$ quantum gates for the modular exponentiaion [(Beckman, Chari, Devabhaktuni, & Preskill, 1996)](https://arxiv.org/pdf/quant-ph/9602016).  Both of these are well beyond the capabilities of modern quantum hardware for numbers of interest. Advancements to reduce the number of gates and qubits required focus on optimizing the kernel for $f(x) = a\cdot x \mod N$ for properties of the number to be factored. The difficulty is to create efficient quantum kernels (in terms of qubit and gate count) that compute $a\cdot x \mod{N}$.
#
# For the purposes of this demonstration, we will consider only the order-finding problem for the values of $a$ to be either $4$ or $5$ with $N=21$. We'll be using the quantum circuits depicted in [this paper](https://arxiv.org/abs/2103.13855) and [this report](https://physlab.org/wp-content/uploads/2023/05/Shor_s_Algorithm_23100113_Fin.pdf), respectively.

# %% [markdown]
# ##### The case N = 21 and a = 5:

# %%
@cudaq.kernel
def modular_mult_5_21(work: cudaq.qview):
    """"Kernel for multiplying by 5 mod 21
    based off of the circuit diagram in 
    https://physlab.org/wp-content/uploads/2023/05/Shor_s_Algorithm_23100113_Fin.pdf
    Modifications were made to change the ordering of the qubits"""
    x(work[0])
    x(work[2])
    x(work[4])
    
    swap(work[0], work[4])
    swap(work[0], work[2])

@cudaq.kernel
def modular_exp_5_21(exponent: cudaq.qview, work: cudaq.qview,
                     control_size: int):
    """ Controlled modular exponentiation kernel used in Shor's algorithm
    |x> U^x |y> = |x> |(5^x)y mod 21>
    """
    x(work[0])
    for exp in range(control_size):
        ctrl_qubit = exponent[exp]
        for _ in range(2**(exp)):
            cudaq.control(modular_mult_5_21, ctrl_qubit, work)

# %% [markdown]
# Verify in the code block below that the kernels defined above do in fact carry out multiplication and exponentiation with $a=5$ and $N=21$ by changing the `iterations` variable below.

# %%
# Demonstrate iterated application of 5y mod 21 where y = 1
@cudaq.kernel
def demonstrate_mod_exponentiation(iterations: int):
    qubits = cudaq.qvector(5)
    x(qubits[0]) # initalizes the qubits in the state for y = 1 which is |10000>
    for _ in range(iterations):
        modular_mult_5_21(qubits)


shots = 200

# The iterations variable determines the exponent in 5^x mod 21. 
# Change this value to verify that the demonstrate_mod_exponentiation
# kernel carries out the desired calculation.
iterations = 1  

print(cudaq.draw(demonstrate_mod_exponentiation, iterations))

results = cudaq.sample(demonstrate_mod_exponentiation,
                       iterations,
                       shots_count=shots)

print("Measurement results from sampling:", results)

# Reverse the order of the most probable measured bit string
# and convert the binary string to an integer
integer_result = int(results.most_probable()[::-1],2)

print("For x = {}, 5^x mod 21 = {}".format(iterations, (5**iterations) % 21))
print("For x = {}, the computed result of the circuit is {}".format(
    iterations, integer_result))
# Out:
#      ╭───╮╭───╮
# q0 : ┤ x ├┤ x ├─╳──╳─
#      ╰───╯╰───╯ │  │
# q1 : ───────────┼──┼─
#      ╭───╮      │  │
# q2 : ┤ x ├──────┼──╳─
#      ╰───╯      │
# q3 : ───────────┼────
#      ╭───╮      │
# q4 : ┤ x ├──────╳────
#      ╰───╯
#
# Measurement results from sampling: { 10100:200 }
#
# For x = 1, 5^x mod 21 = 5
# For x = 1, the computed result of the circuit is 5

# %% [markdown]
# ##### The case N = 21 and a = 4:
#
# The example below is one where the work register has been optimized to use fewer gates and qubits than would have been necessary through a straightforward implementation of modular multiplication as seen in the previous case.

# %%
@cudaq.kernel
def modular_exp_4_21(exponent: cudaq.qview, work: cudaq.qview):
    """ Controlled modular exponentiation kernel used in Shor's algorithm
     |x> U^x |y> = |x> |(4^x)y mod 21>
     based off of the circuit diagram in https://arxiv.org/abs/2103.13855
     Modifications were made to account for qubit ordering differences"""
    swap(exponent[0], exponent[2])
    # x = 1
    x.ctrl(exponent[2], work[1])

    # x = 2
    x.ctrl(exponent[1], work[1])
    x.ctrl(work[1], work[0])
    x.ctrl([exponent[1], work[0]], work[1])
    x.ctrl(work[1], work[0])

    # x = 4
    x(work[1])
    x.ctrl([exponent[0], work[1]], work[0])
    x(work[1])
    x.ctrl(work[1], work[0])
    x.ctrl([exponent[0], work[0]], work[1])
    x.ctrl(work[1], work[0])
    swap(exponent[0], exponent[2])

# %% [markdown]
# Now we are ready to define the `phase_kernel` to carry out the instructions in the circuit diagram drawn at the beginning of this section.

# %%
@cudaq.kernel
def phase_kernel(control_register_size: int, work_register_size: int, a: int,
                 N: int):
    """ 
    Kernel to estimate the phase of the modular multiplication gate |x> U |y> = |x> |a*y mod 21> for a = 4 or 5
    """

    qubits = cudaq.qvector(control_register_size + work_register_size)
    control_register = qubits[0:control_register_size]
    work_register = qubits[control_register_size:control_register_size +
                           work_register_size]

    h(control_register)

    if a == 4 and N == 21:
        modular_exp_4_21(control_register, work_register)
    if a == 5 and N == 21:
        modular_exp_5_21(control_register, work_register, control_register_size)

    inverse_qft(control_register)

    # Measure only the control_register and not the work_register
    mz(control_register)

# %%
control_register_size = 3
work_register_size = 5
values_for_a = [4, 5]
idx = 1  # change to 1 to select 5
N = 21
shots = 15000

print(
    cudaq.draw(phase_kernel, control_register_size, work_register_size,
               values_for_a[idx], N))

results = cudaq.sample(phase_kernel,
                       control_register_size,
                       work_register_size,
                       values_for_a[idx],
                       N,
                       shots_count=shots)
print(
    "Measurement results for a={} and N={} with {} qubits in the control register "
    .format(values_for_a[idx], N, control_register_size))
print(results)
# Out:
#      ╭───╮                                                                    »
# q0 : ┤ h ├──●────●────●───●──●────────────────────────────────────────────────»
#      ├───┤  │    │    │   │  │                                                »
# q1 : ┤ h ├──┼────┼────┼───┼──┼───●────●────●───●──●───●────●────●───●──●──────»
#      ├───┤  │    │    │   │  │   │    │    │   │  │   │    │    │   │  │      »
# q2 : ┤ h ├──┼────┼────┼───┼──┼───┼────┼────┼───┼──┼───┼────┼────┼───┼──┼───●──»
#      ├───┤╭─┴─╮  │    │   │  │ ╭─┴─╮  │    │   │  │ ╭─┴─╮  │    │   │  │ ╭─┴─╮»
# q3 : ┤ x ├┤ x ├──┼────┼───╳──╳─┤ x ├──┼────┼───╳──╳─┤ x ├──┼────┼───╳──╳─┤ x ├»
#      ╰───╯╰───╯  │    │   │  │ ╰───╯  │    │   │  │ ╰───╯  │    │   │  │ ╰───╯»
# q4 : ────────────┼────┼───┼──┼────────┼────┼───┼──┼────────┼────┼───┼──┼──────»
#                ╭─┴─╮  │   │  │      ╭─┴─╮  │   │  │      ╭─┴─╮  │   │  │      »
# q5 : ──────────┤ x ├──┼───┼──╳──────┤ x ├──┼───┼──╳──────┤ x ├──┼───┼──╳──────»
#                ╰───╯  │   │         ╰───╯  │   │         ╰───╯  │   │         »
# q6 : ─────────────────┼───┼────────────────┼───┼────────────────┼───┼─────────»
#                     ╭─┴─╮ │              ╭─┴─╮ │              ╭─┴─╮ │         »
# q7 : ───────────────┤ x ├─╳──────────────┤ x ├─╳──────────────┤ x ├─╳─────────»
#                     ╰───╯                ╰───╯                ╰───╯           »
#
# ################################################################################
#
#                                                                             »
# ────────────────────────────────────────────────────────────────────────────»
#                                                                             »
# ────────────────────────────────────────────────────────────────────────────»
#                                                                             »
# ──●────●───●──●───●────●────●───●──●───●────●────●───●──●───●────●────●───●─»
#   │    │   │  │ ╭─┴─╮  │    │   │  │ ╭─┴─╮  │    │   │  │ ╭─┴─╮  │    │   │ »
# ──┼────┼───╳──╳─┤ x ├──┼────┼───╳──╳─┤ x ├──┼────┼───╳──╳─┤ x ├──┼────┼───╳─»
#   │    │   │  │ ╰───╯  │    │   │  │ ╰───╯  │    │   │  │ ╰───╯  │    │   │ »
# ──┼────┼───┼──┼────────┼────┼───┼──┼────────┼────┼───┼──┼────────┼────┼───┼─»
# ╭─┴─╮  │   │  │      ╭─┴─╮  │   │  │      ╭─┴─╮  │   │  │      ╭─┴─╮  │   │ »
# ┤ x ├──┼───┼──╳──────┤ x ├──┼───┼──╳──────┤ x ├──┼───┼──╳──────┤ x ├──┼───┼─»
# ╰───╯  │   │         ╰───╯  │   │         ╰───╯  │   │         ╰───╯  │   │ »
# ───────┼───┼────────────────┼───┼────────────────┼───┼────────────────┼───┼─»
#      ╭─┴─╮ │              ╭─┴─╮ │              ╭─┴─╮ │              ╭─┴─╮ │ »
# ─────┤ x ├─╳──────────────┤ x ├─╳──────────────┤ x ├─╳──────────────┤ x ├─╳─»
#      ╰───╯                ╰───╯                ╰───╯                ╰───╯   »
#
# ################################################################################
#
#                            ╭─────────────╮╭────────────╮╭───╮
# ───────────────────────────┤ r1(-0.7854) ├┤ r1(-1.571) ├┤ h ├
#         ╭────────────╮╭───╮╰──────┬──────╯╰─────┬──────╯╰───╯
# ────────┤ r1(-1.571) ├┤ h ├───────┼─────────────●────────────
#    ╭───╮╰─────┬──────╯╰───╯       │
# ─●─┤ h ├──────●───────────────────●──────────────────────────
#  │ ╰───╯
# ─╳───────────────────────────────────────────────────────────
#  │
# ─┼───────────────────────────────────────────────────────────
#  │
# ─╳───────────────────────────────────────────────────────────
#
# ─────────────────────────────────────────────────────────────
#
# ─────────────────────────────────────────────────────────────
#
#
# Measurement results for a=5 and N=21 with 3 qubits in the control register
# { 000:2762 010:889 111:1798 001:1929 011:1899 100:2907 101:1888 110:928 }

# %% [markdown]
# ### Determining the order from the measurement results of the phase kernel
#
# The measurement results from sampling the `phase_kernel` can be used to estimate the phase of the operator $U|x\rangle = ax\mod N$. We will only be interested in the most probable non-zero outcomes of the sampling.  Therefore, we'll create a function `top_results` to extract those values.

# %%
def top_results(sample_results, zeros, threshold):
    """Function to output the non-zero results whose counts are above the given threshold
    Returns
    -------
        dict[str, int]: keys are bit-strings and values are the respective counts  
    """
    results_dictionary = {k: v for k, v in sample_results.items()}
    if zeros in results_dictionary.keys():
        results_dictionary.pop(zeros)
    sorted_results = {
        k: v for k, v in sorted(
            results_dictionary.items(), key=lambda item: item[1], reverse=True)
    }
    top_key = next(iter(sorted_results))
    max_value = sorted_results[top_key]
    top_results_dictionary = {top_key: max_value}

    for key in sorted_results:
        if results_dictionary[key] > min(threshold, max_value):
            top_results_dictionary[key] = results_dictionary[key]
    return top_results_dictionary

# %% [markdown]
# Let's see how the `top_results` extracts the top results from the measurement results for a=4 and N=21 with 3 qubits in the control register that we computed above.  One of these top result is likely to be an estimate for the phase of $U$.

# %%
# Example
top_results(results, '000', 750)
# Out:
# {'100': 2907,
#  '001': 1929,
#  '011': 1899,
#  '101': 1888,
#  '111': 1798,
#  '110': 928,
#  '010': 889}

# %% [markdown]
# The algorithm for translating the phase estimate of the operator $U|x\rangle = ax\mod N$ into the order of $a \mod N$ involves continued fractions. The function `find_order_quantum` below carries out this computation.  To learn more about how the phase of $U$ relates to the period of $a \mod N$, check out these three lectures by Scott Aaronson: lecture [19](https://www.scottaaronson.com/qclec/19.pdf), [20](https://www.scottaaronson.com/qclec/20.pdf), [21](https://www.scottaaronson.com/qclec/21.pdf).

# %%
def get_order_from_phase(phase, phase_nbits, a, N):
    """Uses continued fractions to find the order of a mod N  
    Parameters
    ----------
    phase: int
        Integer result from the phase estimate of U|x> = ax mod N
    phase_nbits: int
        Number of qubits used to estimate the phase
    a: int
        For this demonstration a is either 4 or 5
    N: int
        For this demonstration N = 21
    Returns
    -------
    int: period of a mod N if found, otherwise returns None
    """

    assert phase_nbits > 0
    assert a > 0
    assert N > 0

    eigenphase = float(phase) / 2**(phase_nbits)

    f = fractions.Fraction.from_float(eigenphase).limit_denominator(N)

    if f.numerator == 1:
        return None
    eigenphase = float(f.numerator / f.denominator)
    print('eigenphase is ', eigenphase)
    coefficients_continued_fraction = list(
        contfrac.continued_fraction(eigenphase))
    
    convergents_continued_fraction = list(contfrac.convergents(eigenphase))
    print('convergent sequence of fractions for this eigenphase is', convergents_continued_fraction)
    for r in convergents_continued_fraction:
        print('using the denominators of the fractions in the convergent sequence, testing order =', r[1])
        if a**r[1] % N == 1:
            print('Found order:', r[1])
            return (r[1])
    return None

# %% [markdown]
# We are now ready to combine all the elements above into a function to find the order of $a$ $\mod N$ and test it in the factoring algoithm.

# %%
def find_order_quantum(a, N):
    """The quantum algorithm to find the order of a mod N, when x = 4 or x =5 and N = 21
    Parameters
    ----------
    a: int
        For this demonstration a will be either 4 or 5
    N: int
        For this demonstration N will be 21
    Returns
    r: int the period if it is found, or None if no period is found
    -------
    
    """

    if (a == 4 and N == 21) or (a == 5 and N == 21):
        shots = 15000
        if a == 4 and N == 21:
            control_register_size = 3
            work_register_size = 2
        if a == 5 and N == 21:
            control_register_size = 5
            work_register_size = 5

        #cudaq.set_random_seed(123)
        results = cudaq.sample(phase_kernel,
                               control_register_size,
                               work_register_size,
                               a,
                               N,
                               shots_count=shots)
        print("Measurement results:")
        print(results)

        # We will want to ignore the all zero result
        zero_result = ''.join(
            [str(elem) for elem in [0] * control_register_size])
        # We'll only consider the top results from the sampling
        threshold = shots * (.1)
        most_probable_bitpatterns = top_results(results, zero_result, threshold)

        for key in most_probable_bitpatterns:
            # Convert the key bit string into an integer 
            # This integer divided by 8 is an estimate for the phase
            reverse_result = key[::-1]
            phase = int(reverse_result, 2)
            
            print("Trying nonzero bitpattern from the phase estimation:", key,
                  "=", phase)
            r = get_order_from_phase(phase, control_register_size, a, N)
            if r == None:
                print('No period found.')

                continue

            return r
            break
    else:
        print(
            "A different quantum kernel is required for this choice of a and N."
        )

# %%
my_integer = 21
initial_value_to_start = 5  # Try replacing 5 with 4
quantum = True 
shors_algorithm(my_integer, initial_value_to_start, quantum)
# Out:
# Trying a = 5
# Measurement results:
# { 11010:431 11001:106 11101:35 00000:2431 01001:93 00100:128 01011:1681 00101:1727 10101:1679 00110:427 11111:19 01000:47 01101:42 01110:23 01010:460 11110:21 01111:19 00011:55 01100:120 10011:38 00010:22 00001:24 11011:1821 00111:83 11100:112 10001:28 10010:26 10100:112 10110:454 10000:2571 10111:92 11000:73 }
#
# Trying nonzero bitpattern from the phase estimation: 10000 = 1
# No period found.
# Trying nonzero bitpattern from the phase estimation: 11011 = 27
# eigenphase is  0.8421052631578947
# convergent sequence of fractions for this eigenphase is [(0, 1), (1, 1), (5, 6), (16, 19)]
# using the denominators of the fractions in the convergent sequence, testing order = 1
# using the denominators of the fractions in the convergent sequence, testing order = 1
# using the denominators of the fractions in the convergent sequence, testing order = 6
# Found order: 6
# The order of a = 5 is 6
# Found factors of N = 21: 7 and 3
# 1 attempts
# (7, 3)

# %% [markdown]
# ### Postscript
# Recent [work of Oded Regev](https://arxiv.org/abs/2308.06572) improves Shor's Algorithm by reducing the number of gates needed.  You can read more about it [here](https://www.quantamagazine.org/thirty-years-later-a-speed-boost-for-quantum-factoring-20231017/).
